# %%
# %run ../00-common/config

# %%
# %run ../00-common/bronze_helpers

# %%
# %run ../00-common/schemas

# %%
from pyspark.sql import functions as F

# lexo customers nga landing me skemen e percaktuar
customers_raw = (spark.read.format("csv").option("header", True)
    .schema(customers_schema)
    .load(f"{landing_folder_path}/olist_customers_dataset.csv"))

# %%
# shkruaj customers ne bronze si tabele delta
target_table = f"{catalog_name}.{bronze_schema}.customers"

write_to_bronze(customers_raw, target_table)

print(f"Wrote {customers_raw.count():,} rows to {target_table}")
