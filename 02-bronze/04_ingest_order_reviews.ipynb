# %%
# %run ../00-common/config

# %%
# %run ../00-common/bronze_helpers

# %%
# %run ../00-common/schemas

# %%
from pyspark.sql import functions as F

# lexo order_reviews nga landing me skemen e percaktuar
order_reviews_raw = (spark.read.format("csv")
    .option("header", True)
    .option("multiLine", True)   # komente me rreshta te rinj brenda
    .option("escape", '"')          # thonjza brenda tekstit
    .schema(order_reviews_schema)
    .load(f"{landing_folder_path}/olist_order_reviews_dataset.csv"))

# %%
# shkruaj order_reviews ne bronze si tabele delta
target_table = f"{catalog_name}.{bronze_schema}.order_reviews"

write_to_bronze(order_reviews_raw, target_table, batch_id="batch_001")

print(f"Wrote {order_reviews_raw.count():,} rows to {target_table}")
