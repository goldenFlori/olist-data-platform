# %%
# %run ../00-common/config

# %%
# %run ../00-common/bronze_helpers

# %%
# %run ../00-common/schemas

# %%
from pyspark.sql import functions as F

# lexo geolocation nga landing me skemen e percaktuar
geolocation_raw = (spark.read.format("csv").option("header", True)
    .schema(geolocation_schema)
    .load(f"{landing_folder_path}/olist_geolocation_dataset.csv"))

# %%
# shkruaj geolocation ne bronze si tabele delta, ndaj sipas state (tabela me e madhe, 1M rreshta)
target_table = f"{catalog_name}.{bronze_schema}.geolocation"

write_to_bronze(geolocation_raw, target_table, batch_id="batch_001", partition_col="geolocation_state")

print(f"Wrote {geolocation_raw.count():,} rows to {target_table}")
