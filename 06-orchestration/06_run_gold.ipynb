# %%
# orkestron shtresen gold, dimensionet para fakteve
gold_notebooks = [
    "01_dim_date",
    "02_dim_customer",
    "03_dim_product",
    "04_dim_seller",
    "05_dim_geography",
    "06_fact_orders",
    "07_fact_order_items",
    "08_fact_payments",
    "09_agg_daily_category",
]

for nb in gold_notebooks:
    print(f"Running gold/{nb} ...")
    dbutils.notebook.run(f"../04-gold/{nb}", 600)

print("Gold layer complete")
