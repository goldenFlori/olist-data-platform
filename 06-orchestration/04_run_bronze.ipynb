# %%
# %run ../00-common/config

# %%
# orkestron shtresen bronze, therret te 9 ingestimet me radhe
bronze_notebooks = [
    "01_ingest_orders",
    "02_ingest_order_items",
    "03_ingest_order_payments",
    "04_ingest_order_reviews",
    "05_ingest_customers",
    "06_ingest_sellers",
    "07_ingest_products",
    "08_ingest_geolocation",
    "09_ingest_category_tr",
]

for nb in bronze_notebooks:
    print(f"Running bronze/{nb} ...")
    dbutils.notebook.run(f"../02-bronze/{nb}", 600)

print("Bronze layer complete")
