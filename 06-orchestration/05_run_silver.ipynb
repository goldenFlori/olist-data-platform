# %%
# orkestron shtresen silver, pastrimi, ne rendin e varesive
silver_notebooks = [
    "02_customers",
    "03_sellers",
    "04_category_tr",
    "05_products",
    "06_geolocation",
    "07_order_items",
    "08_order_payments",
    "09_orders",
    "10_order_reviews",
]

for nb in silver_notebooks:
    print(f"Running silver/{nb} ...")
    dbutils.notebook.run(f"../03-silver/{nb}", 600)

print("Silver layer complete")
