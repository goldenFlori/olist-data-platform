# %%
# %run ../00-common/config

# %%
# %run ./00_silver_helpers

# %%
from pyspark.sql import functions as F

payments = spark.table(f"{catalog_name}.{bronze_schema}.order_payments").drop("ingestion_timestamp", "source_file")

# quarantine pagesat me vlere <= 0,,s'kane kuptim biznesi
payments_valid = split_and_quarantine(
    payments,
    valid_condition=F.col("payment_value") > 0,
    reject_reason="payment_value <= 0",
    table_name="order_payments",
    catalog=catalog_name,
    quarantine_schema=quarantine_schema
)

write_to_silver(payments_valid, "order_payments", catalog_name, silver_schema)
