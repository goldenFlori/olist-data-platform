# %%
# %run ../00-common/config

# %%
# %run ./00_silver_helpers

# %%
from pyspark.sql import functions as F

# customers ishte i paster ne profilim, pa null, pa dublikata
customers = spark.table(f"{catalog_name}.{bronze_schema}.customers")

# heq kolonat e metadata te bronze-it (do i rifusim vetem ku duhen)
customers_silver = customers.drop("ingestion_timestamp", "source_file")
    

write_to_silver(customers_silver, "customers", catalog_name, silver_schema)
