# %%
# %run ../00-common/config

# %%
# %run ./00_silver_helpers

# %%
order_items = spark.table(f"{catalog_name}.{bronze_schema}.order_items").drop("ingestion_timestamp", "source_file")
# i paster ne profilim
write_to_silver(order_items, "order_items", catalog_name, silver_schema)
