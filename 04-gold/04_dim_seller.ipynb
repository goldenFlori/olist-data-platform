# %%
# %run ../00-common/config

# %%
sellers = spark.table(f"{catalog_name}.{silver_schema}.sellers")

# merr shitesit nga silver, mban vetem kolonat qe na duhen
dim_seller = sellers.select(
    "seller_id", "seller_zip_code_prefix", "seller_city", "seller_state"
)

(dim_seller.write.format("delta").mode("overwrite").option("overwriteSchema", "true")
    .saveAsTable(f"{catalog_name}.{gold_schema}.dim_seller"))
print(f"Wrote {dim_seller.count():,} sellers")
